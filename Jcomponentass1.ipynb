# %%
import pandas as pd
df=pd.read_csv('/content/Life Expectancy Data_-338153872.csv')

# %%
from matplotlib import pyplot as p
y=df['Life expectancy ']
x=df['Year']
plt.ylabel("life expectancy")
plt.xlabel("year")
p.plot(x,y)

# %%
from matplotlib import pyplot as p
y=df['Life expectancy ']
x=df['Adult Mortality']
plt.ylabel("life expectancy")
plt.xlabel("Adult Mortality")
p.plot(x,y)

# %%
from matplotlib import pyplot as p
y=df['Life expectancy ']
x=df['infant deaths']
plt.ylabel("life expectancy")
plt.xlabel("infant deaths")
p.plot(x,y)

# %%
from matplotlib import pyplot as p
y=df['Life expectancy ']
x=df['Alcohol']
plt.ylabel("life expectancy")
plt.xlabel("Alcohol")
p.plot(x,y)

# %%
from matplotlib import pyplot as p
y=df['Life expectancy ']
x=df['percentage expenditure']
plt.ylabel("life expectancy")
plt.xlabel("percentage expenditure")
p.plot(x,y)

# %%
from matplotlib import pyplot as p
y=df['Life expectancy ']
x=df['Hepatitis B']
plt.ylabel("life expectancy")
plt.xlabel("Hepatitis B")
p.plot(x,y)

# %%
from matplotlib import pyplot as p
y=df['Life expectancy ']
x=df['Measles ']
plt.ylabel("life expectancy")
plt.xlabel("Measles ")
p.plot(x,y)

# %%
from matplotlib import pyplot as p
y=df['Life expectancy ']
x=df[' BMI ']
plt.ylabel("life expectancy")
plt.xlabel(" BMI ")
p.plot(x,y)

# %%
from matplotlib import pyplot as p
y=df['Life expectancy ']
x=df['under-five deaths ']
plt.ylabel("life expectancy")
plt.xlabel("under-five deaths ")
p.plot(x,y)

# %%
from matplotlib import pyplot as p
y=df['Life expectancy ']
x=df['Polio']
plt.ylabel("life expectancy")
plt.xlabel("Polio")
p.plot(x,y)

# %%
from matplotlib import pyplot as p
y=df['Life expectancy ']
x=df['Total expenditure']
plt.ylabel("life expectancy")
plt.xlabel("Total expenditure")
p.plot(x,y)

# %%
from matplotlib import pyplot as p
y=df['Life expectancy ']
x=df['Diphtheria ']
plt.ylabel("life expectancy")
plt.xlabel("Diphtheria ")
p.plot(x,y)

# %%
from matplotlib import pyplot as p
y=df['Life expectancy ']
x=df[' HIV/AIDS']
plt.ylabel("life expectancy")
plt.xlabel(" HIV/AIDS")
p.plot(x,y)

# %%
from matplotlib import pyplot as p
y=df['Life expectancy ']
x=df['GDP']
plt.ylabel("life expectancy")
plt.xlabel("GDP")
p.plot(x,y)

# %%
from matplotlib import pyplot as p
y=df['Life expectancy ']
x=df['Population']
plt.ylabel("life expectancy")
plt.xlabel("Population")
p.plot(x,y)

# %%
from matplotlib import pyplot as p
y=df['Life expectancy ']
x=df[' thinness  1-19 years']
plt.ylabel("life expectancy")
plt.xlabel(" thinness  1-19 years")
p.plot(x,y)

# %%
from matplotlib import pyplot as p
y=df['Life expectancy ']
x=df[' thinness 5-9 years']
plt.ylabel("life expectancy")
plt.xlabel(" thinness 5-9 years")
p.plot(x,y)

# %%
from matplotlib import pyplot as p
y=df['Life expectancy ']
x=df['Income composition of resources']
plt.ylabel("life expectancy")
plt.xlabel("Income composition of resources")
p.plot(x,y)

# %%
from matplotlib import pyplot as p
y=df['Life expectancy ']
x=df['Schooling']
plt.ylabel("life expectancy")
plt.xlabel("Schooling")
p.plot(x,y)
